# %%
import pandas as pd

# %%
filename = "M5_vs_db1.csv"
# filename = "M5_vs_db2.csv"
spreadsheet = pd.read_csv(filename)
spreadsheet
# Out:
#                                                  Name  \
# 0                          170 MNXM1107906 superoxide
# 1                          19 MNXM1094289 thiosulfate
# 2                     715 MNXM737997 (2R,3R)-tartrate
# 3              529 MNXM727604 (2R)-3-phosphoglycerate
# 4                   25 MNXM1101251 2-hydroxyglutarate
# 5       200 MNXM1170 3-dehydro-L-gulonate 6-phosphate
# 6                             261 MNXM1608 (R)-malate
# 7                        272 MNXM164710 D-erythronate
# 8                        609 MNXM732052 (R)-glycerate
# 9                           215 MNXM1275 D-methionine
# 10          448 MNXM529 meso-2,6-diaminoheptanedioate
# 11              430 MNXM475 2-hydroxy-3-oxopropanoate
# 12     645 MNXM733877 2-hydroxypenta-2,4-dienoic acid
# 13  518 MNXM726882 2-hydroxy-6-oxonona-2,4,7-trien...
# 14                            367 MNXM331 D-glutamate
# 15  173 MNXM1107974 2-hydroxy-6-oxonona-2,4-diened...
# ...

# %%
# filename = "M5_vs_db1.csv"
filename = "M5_vs_db2.csv"
spreadsheet = pd.read_csv(filename)
spreadsheet
# Out:
#                                                  Name  \
# 0                              MNXM1107906_superoxide
# 1                                MNXM741004_tungstate
# 2                                MNXM726092_molybdate
# 3                             MNXM1094289_thiosulfate
# 4                         MNXM737997_(2R,3R)-tartrate
# 5                                   MNXM222_glycolate
# 6               MNXM854_5-dehydro-4-deoxy-D-glucarate
# 7                      MNXM1101251_2-hydroxyglutarate
# 8                            MNXM164710_D-erythronate
# 9                  MNXM727604_(2R)-3-phosphoglycerate
# 10                           MNXM732052_(R)-glycerate
# 11                   MNXM1407_4-phospho-D-erythronate
# 12              MNXM529_meso-2,6-diaminoheptanedioate
# 13                             MNXM731835_(S)-lactate
# 14                  MNXM475_2-hydroxy-3-oxopropanoate
# 15         MNXM730319_2(alpha-D-Mannosyl)-D-glycerate
# ...
